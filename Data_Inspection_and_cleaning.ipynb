# %% [markdown]
# <a href="https://colab.research.google.com/github/Urvashishasne/Women-Safety-Risk-Analysis/blob/main/Data_Inspection_and_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
path =('/content/drive/MyDrive/Women_Safety_Risk_Analysis_data')

# %%
files = os.listdir(path)
for file in files:
  print(file)
# Out:
# 42_Cases_under_crime_against_women.csv
# 43_Arrests_under_crime_against_women.csv
# 20_Victims_of_rape.csv
# 39_Specific_purpose_of_kidnapping_and_abduction.csv
# 32_Murder_victim_age_sex.csv
# 33_CH_not_murder_victim_age_sex.csv
# 25_Complaints_against_police.csv
# 35_Human_rights_violation_by_police.csv

# %%
# read each file one by one
Cases_under_crime_against_women = pd.read_csv(path + "/42_Cases_under_crime_against_women.csv", on_bad_lines='skip')
Arrests_under_crime_against_women= pd.read_csv(path + "/43_Arrests_under_crime_against_women.csv", on_bad_lines='skip')
Victims_of_rape_data= pd.read_csv(path + "/20_Victims_of_rape.csv", on_bad_lines='skip')
Specific_purpose_of_kidnapping_and_abduction= pd.read_csv(path + "/39_Specific_purpose_of_kidnapping_and_abduction.csv", on_bad_lines='skip')
Murder_victim_data= pd.read_csv(path + "/32_Murder_victim_age_sex.csv", on_bad_lines='skip')
CH_not_murder_victim_data= pd.read_csv(path + "/33_CH_not_murder_victim_age_sex.csv", on_bad_lines='skip')
Complaints_against_police= pd.read_csv(path + "/25_Complaints_against_police.csv", on_bad_lines='skip')
Human_rights_violation_by_police= pd.read_csv(path + "/35_Human_rights_violation_by_police.csv", on_bad_lines='skip')

# %%
Cases_under_crime_against_women.head(3)
# Out:
#                    Area_Name  Year Group_Name Sub_Group_Name  \
# 0  Andaman & Nicobar Islands  2001       Rape       01. Rape
# 1             Andhra Pradesh  2001       Rape       01. Rape
# 2          Arunachal Pradesh  2001       Rape       01. Rape
#
#    Cases_Acquitted_or_Discharged  \
# 0                              5
# 1                            731
# 2                              1
#
#    Cases_charge_sheets_were_not_laid_but_Final_Report_submitted  \
# 0                                                  2
# 1                                                 22
# 2                                                  2
#
#    Cases_Chargesheeted  Cases_Compounded_or_Withdrawn  Cases_Convicted  \
# 0                    3                              0                0
# 1                  769                             35              197
# 2                   25                              0                2
#
# ...

# %%
Cases_under_crime_against_women.shape
# Out:
# (2765, 22)

# %%
Cases_under_crime_against_women.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2765 entries, 0 to 2764
# Data columns (total 22 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Area_Name                                                     2765 non-null   object
#  1   Year                                                          2765 non-null   int64
#  2   Group_Name                                                    2765 non-null   object
#  3   Sub_Group_Name                                                2765 non-null   object
#  4   Cases_Acquitted_or_Discharged                                 2765 non-null   int64
#  5   Cases_charge_sheets_were_not_laid_but_Final_Report_submitted  2765 non-null   int64
#  6   Cases_Chargesheeted                                           2765 non-null   int64
# ...

# %%
Cases_under_crime_against_women.columns
# Out:
# Index(['Area_Name', 'Year', 'Group_Name', 'Sub_Group_Name',
#        'Cases_Acquitted_or_Discharged',
#        'Cases_charge_sheets_were_not_laid_but_Final_Report_submitted',
#        'Cases_Chargesheeted', 'Cases_Compounded_or_Withdrawn',
#        'Cases_Convicted',
#        'Cases_Declared_False_on_Account_of_Mistake_of_Fact_or_of_Law',
#        'Cases_Investigated_Chargesheets+FR_Submitted',
#        'Cases_not_Investigated_or_in_which_investigation_was_refused',
#        'Cases_Pending_Investigation_at_Year_End',
#        'Cases_Pending_Investigation_from_previous_year',
#        'Cases_Pending_Trial_at_Year_End',
#        'Cases_Pending_Trial_from_the_previous_year', 'Cases_Reported',
#        'Cases_Sent_for_Trial', 'Cases_Trials_Completed',
#        'Cases_Withdrawn_by_the_Govt',
#        'Cases_withdrawn_by_the_Govt_during_investigation',
#        'Total_Cases_for_Trial'],
#       dtype='object')

# %%
Cases_under_crime_against_women.isnull().sum()
# Out:
# Area_Name                                                       0
# Year                                                            0
# Group_Name                                                      0
# Sub_Group_Name                                                  0
# Cases_Acquitted_or_Discharged                                   0
# Cases_charge_sheets_were_not_laid_but_Final_Report_submitted    0
# Cases_Chargesheeted                                             0
# Cases_Compounded_or_Withdrawn                                   0
# Cases_Convicted                                                 0
# Cases_Declared_False_on_Account_of_Mistake_of_Fact_or_of_Law    0
# Cases_Investigated_Chargesheets+FR_Submitted                    0
# Cases_not_Investigated_or_in_which_investigation_was_refused    0
# Cases_Pending_Investigation_at_Year_End                         0
# Cases_Pending_Investigation_from_previous_year                  0
# ...

# %%
# duplicates
Cases_under_crime_against_women.duplicated().sum()
# Out:
# np.int64(0)

# %%
# summary statistics
Cases_under_crime_against_women.describe()
# Out:
#               Year  Cases_Acquitted_or_Discharged  \
# count  2765.000000                    2765.000000
# mean   2005.468354                     432.139241
# std       2.877031                    1053.222306
# min    2001.000000                       0.000000
# 25%    2003.000000                       0.000000
# 50%    2005.000000                      26.000000
# 75%    2008.000000                     370.000000
# max    2010.000000                   11606.000000
#
#        Cases_charge_sheets_were_not_laid_but_Final_Report_submitted  \
# count                                        2765.000000
# mean                                           68.478843
# std                                           226.466541
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             5.000000
# 75%                                            37.000000
# ...

# %%
# categorical columns in data
Cases_under_crime_against_women['Year'].unique() # 2001-2010
Cases_under_crime_against_women['Year'].value_counts() # 280 for each year,only 2008 has 245
Cases_under_crime_against_women['Area_Name'].nunique() # total unique area count - 35
Cases_under_crime_against_women['Area_Name'].value_counts() # each has 79 counts
Cases_under_crime_against_women['Group_Name'].nunique() # total 8 group name
Cases_under_crime_against_women['Group_Name'].value_counts() # each has count - 350 , only total crime againt women -315
Cases_under_crime_against_women['Sub_Group_Name'].unique()# 8
Cases_under_crime_against_women['Sub_Group_Name'].value_counts() #each 350
# Out:
# Sub_Group_Name
# 01. Rape                                       350
# 02. Kidnapping & Abduction of Women & Girls    350
# 03. Dowry Deaths                               350
# 04. Molestation                                350
# 05. Sexual Harassment                          350
# 06. Cruelty by Husband and Relatives           350
# 07. Importation of Girls                       350
# 12. Total Crimes Against Women                 315
# Name: count, dtype: int64

# %%
# since groupname and subgroupname column has same values as result shows- verifing
(Cases_under_crime_against_women['Group_Name'] == Cases_under_crime_against_women['Sub_Group_Name']).all() # returning false mean value are not identical but again
Cases_under_crime_against_women[Cases_under_crime_against_women['Group_Name'] != Cases_under_crime_against_women['Sub_Group_Name']]
# Out:
#                       Area_Name  Year                 Group_Name  \
# 0     Andaman & Nicobar Islands  2001                       Rape
# 1                Andhra Pradesh  2001                       Rape
# 2             Arunachal Pradesh  2001                       Rape
# 3                         Assam  2001                       Rape
# 4                         Bihar  2001                       Rape
# ...                         ...   ...                        ...
# 2760                 Tamil Nadu  2010  Total Crime Against Women
# 2761                    Tripura  2010  Total Crime Against Women
# 2762              Uttar Pradesh  2010  Total Crime Against Women
# 2763                Uttarakhand  2010  Total Crime Against Women
# 2764                West Bengal  2010  Total Crime Against Women
#
#                       Sub_Group_Name  Cases_Acquitted_or_Discharged  \
# 0                           01. Rape                              5
# ...

# %%
#subgroup name has prefix thats why result shows values are not identical
# remove prefix using regex
Cases_under_crime_against_women['Sub_Group_Name'] = Cases_under_crime_against_women['Sub_Group_Name'].str.replace(r'^\d+\.\s+', '', regex=True)
Cases_under_crime_against_women['Sub_Group_Name'].head(5)
# Out:
# 0    Rape
# 1    Rape
# 2    Rape
# 3    Rape
# 4    Rape
# Name: Sub_Group_Name, dtype: object

# %%
(Cases_under_crime_against_women['Group_Name'] == Cases_under_crime_against_women['Sub_Group_Name']).all()
Cases_under_crime_against_women[Cases_under_crime_against_women['Group_Name'] != Cases_under_crime_against_women['Sub_Group_Name']]
# Out:
#                       Area_Name  Year                              Group_Name  \
# 350   Andaman & Nicobar Islands  2001  Kidnapping & Abduction - Women & Girls
# 351              Andhra Pradesh  2001  Kidnapping & Abduction - Women & Girls
# 352           Arunachal Pradesh  2001  Kidnapping & Abduction - Women & Girls
# 353                       Assam  2001  Kidnapping & Abduction - Women & Girls
# 354                       Bihar  2001  Kidnapping & Abduction - Women & Girls
# ...                         ...   ...                                     ...
# 2760                 Tamil Nadu  2010               Total Crime Against Women
# 2761                    Tripura  2010               Total Crime Against Women
# 2762              Uttar Pradesh  2010               Total Crime Against Women
# 2763                Uttarakhand  2010               Total Crime Against Women
# 2764                West Bengal  2010               Total Crime Against Women
#
# ...

# %% [markdown]
# sub group name - Total Crimes Against Women  <br>
# in groupname -Total Crime Against Women<br>
# sub group name -Kidnapping & Abduction of Women & Girls<br>
# in groupname -Kidnapping & Abduction - Women & Girls<br>
# drop group name as both column are same just formatting diffrence.<br>
# as we had already cleaned sub group name column

# %%
Cases_under_crime_against_women = Cases_under_crime_against_women.drop(columns=['Group_Name'])

# %%
useful_cols = ['Area_Name','Year','Sub_Group_Name','Cases_Reported','Cases_Chargesheeted','Cases_Convicted',
'Cases_Pending_Investigation_at_Year_End','Cases_Pending_Trial_at_Year_End','Total_Cases_for_Trial']
